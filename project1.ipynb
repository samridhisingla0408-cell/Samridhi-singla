# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import numpy as nd

# %%
df=pd.read_csv("carbon.csv")

# %%
df
# Out:
#           Country  Region        Date  Kilotons of Co2  Metric Tons Per Capita
# 0     Afghanistan    Asia  01-01-2011           8930.0                    0.31
# 1     Afghanistan    Asia  01-01-2012           8080.0                    0.27
# 2     Afghanistan    Asia  01-01-2010           7110.0                    0.25
# 3     Afghanistan    Asia  01-01-2019           6080.0                    0.16
# 4     Afghanistan    Asia  01-01-2018           6070.0                    0.17
# ...           ...     ...         ...              ...                     ...
# 5672     Zimbabwe  Africa  01-01-2004           9770.0                    0.80
# 5673     Zimbabwe  Africa  01-01-2007           9760.0                    0.78
# 5674     Zimbabwe  Africa  01-01-2010           9600.0                    0.75
# 5675     Zimbabwe  Africa  01-01-2009           7750.0                    0.61
# 5676     Zimbabwe  Africa  01-01-2008           7600.0                    0.61
#
# [5677 rows x 5 columns]

# %%
df.head()
# Out:
#        Country Region        Date  Kilotons of Co2  Metric Tons Per Capita
# 0  Afghanistan   Asia  01-01-2011           8930.0                    0.31
# 1  Afghanistan   Asia  01-01-2012           8080.0                    0.27
# 2  Afghanistan   Asia  01-01-2010           7110.0                    0.25
# 3  Afghanistan   Asia  01-01-2019           6080.0                    0.16
# 4  Afghanistan   Asia  01-01-2018           6070.0                    0.17

# %%
df.tail()
# Out:
#        Country  Region        Date  Kilotons of Co2  Metric Tons Per Capita
# 5672  Zimbabwe  Africa  01-01-2004           9770.0                    0.80
# 5673  Zimbabwe  Africa  01-01-2007           9760.0                    0.78
# 5674  Zimbabwe  Africa  01-01-2010           9600.0                    0.75
# 5675  Zimbabwe  Africa  01-01-2009           7750.0                    0.61
# 5676  Zimbabwe  Africa  01-01-2008           7600.0                    0.61

# %%
df.describe()
# Out:
#        Kilotons of Co2  Metric Tons Per Capita
# count     5.677000e+03             5677.000000
# mean      1.412292e+05                4.325505
# std       6.491258e+05                5.503834
# min       0.000000e+00                0.000000
# 25%       1.380000e+03                0.570000
# 50%       9.170000e+03                2.360000
# 75%       5.848000e+04                6.340000
# max       1.070722e+07               47.650000

# %%
df.isnull()
# Out:
#       Country  Region   Date  Kilotons of Co2  Metric Tons Per Capita
# 0       False   False  False            False                   False
# 1       False   False  False            False                   False
# 2       False   False  False            False                   False
# 3       False   False  False            False                   False
# 4       False   False  False            False                   False
# ...       ...     ...    ...              ...                     ...
# 5672    False   False  False            False                   False
# 5673    False   False  False            False                   False
# 5674    False   False  False            False                   False
# 5675    False   False  False            False                   False
# 5676    False   False  False            False                   False
#
# [5677 rows x 5 columns]

# %%
df.notnull()
# Out:
#       Country  Region  Date  Kilotons of Co2  Metric Tons Per Capita
# 0        True    True  True             True                    True
# 1        True    True  True             True                    True
# 2        True    True  True             True                    True
# 3        True    True  True             True                    True
# 4        True    True  True             True                    True
# ...       ...     ...   ...              ...                     ...
# 5672     True    True  True             True                    True
# 5673     True    True  True             True                    True
# 5674     True    True  True             True                    True
# 5675     True    True  True             True                    True
# 5676     True    True  True             True                    True
#
# [5677 rows x 5 columns]

# %%
df.shape
# Out:
# (5677, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5677 entries, 0 to 5676
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 5677 non-null   object
#  1   Region                  5677 non-null   object
#  2   Date                    5677 non-null   object
#  3   Kilotons of Co2         5677 non-null   float64
#  4   Metric Tons Per Capita  5677 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 221.9+ KB

# %%
df["Kilotons of Co2"].max()
# Out:
# 10707219.73

# %%
df["Kilotons of Co2"].min
# Out:
# <bound method Series.min of 0       8930.0
# 1       8080.0
# 2       7110.0
# 3       6080.0
# 4       6070.0
#          ...
# 5672    9770.0
# 5673    9760.0
# 5674    9600.0
# 5675    7750.0
# 5676    7600.0
# Name: Kilotons of Co2, Length: 5677, dtype: float64>

# %%
df["Date"].max()
# Out:
# '01-01-2019'

# %%
df["Date"].min()
# Out:
# '01-01-1990'

# %%
plt.plot(df["Date"],df["Kilotons of Co2"])
plt.title("carbon")
plt.xlabel("Kilotons of Co2")
plt.ylabel("Date")
plt.show()

# %%
df['Region'].value_counts().plot(kind='pie')
plt.show()

# %%
df['Metric Tons Per Capita'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Date'].value_counts().plot(kind='bar')
plt.show()

# %%
df.plot(kind="line",x="Region",y="Kilotons of Co2")
plt.show()

# %%
df.plot(kind="scatter",x="Date",y="Kilotons of Co2")
plt.show()

# %%
df['Metric Tons Per Capita'].value_counts().plot(kind='hist')
plt.show()

# %%
df['Country'].value_counts().plot(kind='box')
plt.show()

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Date', 'Kilotons of Co2',
#        'Metric Tons Per Capita'],
#       dtype='object')

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Student
